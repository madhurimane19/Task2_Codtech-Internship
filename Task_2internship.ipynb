# %% [markdown]
# ## Business Case:- To predict total sales by using features like money spent on marketing on indivdual items.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the data
data = pd.read_csv(r'C:\Users\Ai_engineer_course\MLA-1 Linear Regression-20240521T115716Z-001\MLA-1 Linear Regression\Advertising.csv')

# %%
## Call the dataframe and do basic checks
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Domain Analysis

# %% [raw]
# 1)TV	:- Amount spend on TV advertisment.
# 2)Radio	:- Amount spend on Radio advertisment.
# 3)Newspaper	:- Amount spend on Newspaper advertisment.
# 4)Sales:- Sales of product

# %%
#Gives us the statistical information about the numerical columns.
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ***Observation***
# - The distribution of TV advertisment have more spread as compared to others.
# - In one case the company has spend 0 dollars for advertisement on Radio.
# - The cost of advertisment on radio is less while for TV is high.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Step 1 Univariate Analysis
#Analyzing TV
sns.histplot(x=data.TV,kde=True)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='Count'>

# %% [markdown]
# ***Observation***
# - The company has spent around 200-230 dollars around 35 times.
# - Minimum money was spent b/w 40 to 60 dollars.
# - The average money spent on TV advertisement is 147 dollars.

# %%
# Analyszing Radio
sns.histplot(x=data.Radio,kde=True)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
# Aanalyzing Newspaper
sns.histplot(x=data.Newspaper,kde=True)
# By looking at below plot we can say that there are less than 10 months when the marketing cost was high
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
# Step 2 Bivariate Analysis

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Analyzing TV and Sales
sns.scatterplot(x='TV',y='Sales',data=data)
# The more marketing on TV is leading to more sales in the product.
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# ***Observation***
# - Spending after 150 dollars seems to have no significant effect in Sales.
# - Minimum amount spend on TV advertisement is around 0.70 dollars.
# - If we spend around 300 dollars on Tv advertisement the sales we will get is in b/w 12 to 27

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
# Analyzing Radio and Sales
sns.scatterplot(x='Radio',y='Sales',data=data)
# Radio advertisments are not showing much trend for the sales of product.
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
# Analyzing Newsapaper and Sales
sns.scatterplot(x='Newspaper',y='Sales',data=data)
# Newspaper advertisments are not showing much trend for the sales of product.
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
## Step 3 Multivariate Analysis
sns.pairplot(data.drop("Unnamed: 0",axis=1),diag_kind="kde")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Data Preprocessing and Feature Engineering

# %%
# Step 1-Finding missing values
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Step 2- Converting categorical data to numerical data but we do not have categorical data in this dataset

# %%
# Step 3 Checking the outlier
sns.boxplot(x='TV',data=data)
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x='Radio',data=data)
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x='Newspaper',data=data)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# ### Feature Selection

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Step 1 Dropping the unwanted variables
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
## Step 2 Checking the correlation
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Model Creation

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#Step 1 Independent and dependent variable creation
X=data[['TV','Radio','Newspaper']] 
y=data.Sales

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# Step 2 Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
data.shape
# Out:
# (200, 4)

# %%
X_train.shape
# Out:
# (160, 3)

# %%
X_test.shape
# Out:
# (40, 3)

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression 
LR=LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LR.intercept_
# Out:
# 2.871760406359252

# %%
LR.predict(X_test) #predicted value
# Out:
# array([12.68512211, 13.82945163, 18.50843778, 14.05602429, 10.48715129,
#         7.70833359,  8.84575387,  7.57857745, 21.66349899,  7.92263516,
#        12.07290436, 12.27838924, 12.25154077,  6.11015366,  6.7572515 ,
#        14.04329962, 19.43355861, 12.0157834 , 14.77949088, 16.89847406,
#         9.66998338, 18.95680289,  9.42666977, 13.44941736,  6.00898058,
#        21.84127938,  8.86383269, 15.32417057, 18.08432175, 21.29420761,
#         9.74065734, 14.95088244, 10.15842876, 19.94732586, 14.52295661,
#        20.7106614 , 15.1869765 ,  8.37000883,  8.19408919, 18.86348261])

# %%
y_predict=LR.predict(X_test) #Model prediction

# %%
y_test # Actual values
# Out:
# 96     11.7
# 174    11.5
# 150    16.1
# 43     12.9
# 126     6.6
# 32      9.6
# 44      8.5
# 34      9.5
# 47     23.2
# 129     9.7
# 148    10.9
# 190    10.8
# 1      10.4
# 106     7.2
# 119     6.6
# 181    12.2
# 28     18.9
# 67     13.4
# 103    14.7
# 99     17.2
# 138     9.6
# 68     18.9
# 140    10.9
# 167    12.2
# 189     6.7
# 58     23.8
# 66      9.5
# 156    15.3
# 59     18.4
# 55     23.7
# 145    10.3
# 110    13.4
# 82     11.3
# 53     21.2
# 165    11.9
# 185    22.6
# 45     14.9
# 191     9.9
# 49      9.7
# 33     17.4
# Name: Sales, dtype: float64

# %%
y_predict # Values predicted by model
# Out:
# array([12.68512211, 13.82945163, 18.50843778, 14.05602429, 10.48715129,
#         7.70833359,  8.84575387,  7.57857745, 21.66349899,  7.92263516,
#        12.07290436, 12.27838924, 12.25154077,  6.11015366,  6.7572515 ,
#        14.04329962, 19.43355861, 12.0157834 , 14.77949088, 16.89847406,
#         9.66998338, 18.95680289,  9.42666977, 13.44941736,  6.00898058,
#        21.84127938,  8.86383269, 15.32417057, 18.08432175, 21.29420761,
#         9.74065734, 14.95088244, 10.15842876, 19.94732586, 14.52295661,
#        20.7106614 , 15.1869765 ,  8.37000883,  8.19408919, 18.86348261])

# %%
# Step 4 Model Evalution
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import math

# %%
print("Mean_Squared_Error:",mean_squared_error(y_test,y_predict))#Actual Prediction
print("Root_Mean_Squared_Error:",math.sqrt(mean_squared_error(y_test,y_predict))) # root mean squared error
# Out:
# Mean_Squared_Error: 2.3167665952434775
# Root_Mean_Squared_Error: 1.5220928339767839

# %%
print(mean_absolute_error(y_test,y_predict))
# Out:
# 1.270378220510817

# %%
#R2 Score 
score=r2_score(y_test,y_predict)#Actual,Predicted
score
# Out:
# 0.9013369363568293

# %%
X_test.shape
# Out:
# (40, 3)

# %%
## calculation of adjusted r2 score
adjusted_r2 = 1-(1-0.920)*(40-1)/(40-3-1)
adjusted_r2
# Out:
# 0.9133333333333333

# %% [markdown]
# **Assumptions of Linear Regression:**<br>
#     - Linearity: Linear relationship exist between dependent and independent variable. In case of non-linearity, use transformation such as logarthmic, exponential, square root etc <br>
#     - No multicollinearity: If there is multicollinearity its unclear which independent variable explains the dependent variable. <br>
#     - Errors are normally distributed. If not, then confidence interval may become too wide or narrow.
#
# **Pros:**<br>
#     - Simple method<br>
#     - Easy to use and understand<br>
#
# **Cons**<br>
#     - Very sensitive to outliers : often leads to model with low accuracy<br>
#     - It performs well for linearly seperable datasets. So not recommended for most real world applications as it produces simplified results assuming linear relationship between the data.
